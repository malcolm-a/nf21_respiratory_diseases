# %%
import polars as pl
import pandas as pd

# %%
df = pl.read_excel('EDGAR_PM2.5_1970_2022.xlsx', engine='calamine', read_options={"header_row": 9})
#df = pl.read_csv('IHME-GBD_2023_DATA-eaf7b78a-1.csv')
df.head()
# Out:
# shape: (5, 61)
# ┌─────────────┬──────────────┬─────────────┬───────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ IPCC_annex  ┆ C_group_IM24 ┆ Country_cod ┆ Name  ┆ … ┆ Y_2019   ┆ Y_2020   ┆ Y_2021   ┆ Y_2022   │
# │ ---         ┆ _sh          ┆ e_A3        ┆ ---   ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str         ┆ ---          ┆ ---         ┆ str   ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# │             ┆ str          ┆ str         ┆       ┆   ┆          ┆          ┆          ┆          │
# ╞═════════════╪══════════════╪═════════════╪═══════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ Non-Annex_I ┆ Rest Central ┆ ABW         ┆ Aruba ┆ … ┆ 0.000074 ┆ 0.000071 ┆ 0.000074 ┆ 0.000074 │
# │             ┆ America      ┆             ┆       ┆   ┆          ┆          ┆          ┆          │
# │ Non-Annex_I ┆ Rest Central ┆ ABW         ┆ Aruba ┆ … ┆ 0.005304 ┆ 0.005134 ┆ 0.005328 ┆ 0.005328 │
# ...

# %%
df.shape
# Out:
# (5587, 61)

# %%
df.schema
# Out:
# Schema([('IPCC_annex', String),
#         ('C_group_IM24_sh', String),
#         ('Country_code_A3', String),
#         ('Name', String),
#         ('ipcc_code_2006_for_standard_report', String),
#         ('ipcc_code_2006_for_standard_report_name', String),
#         ('Substance', String),
#         ('fossil_bio', String),
#         ('Y_1970', Float64),
#         ('Y_1971', Float64),
#         ('Y_1972', Float64),
#         ('Y_1973', Float64),
#         ('Y_1974', Float64),
#         ('Y_1975', Float64),
#         ('Y_1976', Float64),
#         ('Y_1977', Float64),
#         ('Y_1978', Float64),
#         ('Y_1979', Float64),
#         ('Y_1980', Float64),
#         ('Y_1981', Float64),
#         ('Y_1982', Float64),
#         ('Y_1983', Float64),
#         ('Y_1984', Float64),
#         ('Y_1985', Float64),
#         ('Y_1986', Float64),
#         ('Y_1987', Float64),
#         ('Y_1988', Float64),
#         ('Y_1989', Float64),
#         ('Y_1990', Float64),
# ...

# %%
df.describe
# Out:
# <bound method DataFrame.describe of shape: (5_587, 61)
# ┌─────────────┬────────────┬────────────┬──────────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ IPCC_annex  ┆ C_group_IM ┆ Country_co ┆ Name     ┆ … ┆ Y_2019   ┆ Y_2020   ┆ Y_2021   ┆ Y_2022   │
# │ ---         ┆ 24_sh      ┆ de_A3      ┆ ---      ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ str         ┆ ---        ┆ ---        ┆ str      ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# │             ┆ str        ┆ str        ┆          ┆   ┆          ┆          ┆          ┆          │
# ╞═════════════╪════════════╪════════════╪══════════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ Non-Annex_I ┆ Rest       ┆ ABW        ┆ Aruba    ┆ … ┆ 0.000074 ┆ 0.000071 ┆ 0.000074 ┆ 0.000074 │
# │             ┆ Central    ┆            ┆          ┆   ┆          ┆          ┆          ┆          │
# │             ┆ America    ┆            ┆          ┆   ┆          ┆          ┆          ┆          │
# ...

# %%
df.null_count()
# Out:
# shape: (1, 61)
# ┌────────────┬─────────────────┬─────────────────┬──────┬───┬────────┬────────┬────────┬────────┐
# │ IPCC_annex ┆ C_group_IM24_sh ┆ Country_code_A3 ┆ Name ┆ … ┆ Y_2019 ┆ Y_2020 ┆ Y_2021 ┆ Y_2022 │
# │ ---        ┆ ---             ┆ ---             ┆ ---  ┆   ┆ ---    ┆ ---    ┆ ---    ┆ ---    │
# │ u32        ┆ u32             ┆ u32             ┆ u32  ┆   ┆ u32    ┆ u32    ┆ u32    ┆ u32    │
# ╞════════════╪═════════════════╪═════════════════╪══════╪═══╪════════╪════════╪════════╪════════╡
# │ 0          ┆ 0               ┆ 0               ┆ 0    ┆ … ┆ 453    ┆ 452    ┆ 455    ┆ 455    │
# └────────────┴─────────────────┴─────────────────┴──────┴───┴────────┴────────┴────────┴────────┘

# %%
null_percent = df.select([
    (pl.col(c).null_count() / pl.count() * 100).alias(c)
    for c in df.columns
])
# Out:
# /var/folders/v7/vfpcnz_17cl613m8n8f3_6z40000gn/T/ipykernel_63137/3437421625.py:2: DeprecationWarning: `pl.count()` is deprecated. Please use `pl.len()` instead.
# (Deprecated in version 0.20.5)
#   (pl.col(c).null_count() / pl.count() * 100).alias(c)

# %%
null_percent
# Out:
# shape: (1, 61)
# ┌────────────┬───────────────┬──────────────┬──────┬───┬──────────┬──────────┬──────────┬──────────┐
# │ IPCC_annex ┆ C_group_IM24_ ┆ Country_code ┆ Name ┆ … ┆ Y_2019   ┆ Y_2020   ┆ Y_2021   ┆ Y_2022   │
# │ ---        ┆ sh            ┆ _A3          ┆ ---  ┆   ┆ ---      ┆ ---      ┆ ---      ┆ ---      │
# │ f64        ┆ ---           ┆ ---          ┆ f64  ┆   ┆ f64      ┆ f64      ┆ f64      ┆ f64      │
# │            ┆ f64           ┆ f64          ┆      ┆   ┆          ┆          ┆          ┆          │
# ╞════════════╪═══════════════╪══════════════╪══════╪═══╪══════════╪══════════╪══════════╪══════════╡
# │ 0.0        ┆ 0.0           ┆ 0.0          ┆ 0.0  ┆ … ┆ 8.108108 ┆ 8.090209 ┆ 8.143905 ┆ 8.143905 │
# └────────────┴───────────────┴──────────────┴──────┴───┴──────────┴──────────┴──────────┴──────────┘

# %%
num_dups = df.is_duplicated().sum()
print(num_dups)
# Out:
# 0
